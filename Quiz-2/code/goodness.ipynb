# %%
import json
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Student Account/AppData/Local/Microsoft/WindowsApps/python3.11.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
def get_all_json_keys(json_object, parent_key='', keys=None):
    if keys is None:
        keys = []

    if isinstance(json_object, dict):
        for key, value in json_object.items():
            full_key = f"{parent_key}.{key}" if parent_key else key
            keys.append(full_key)
            get_all_json_keys(value, full_key, keys)

    elif isinstance(json_object, list):
        if json_object:
            # Just handle the first element to get the structure
            get_all_json_keys(json_object[0], parent_key, keys)

    return keys

# %%
file = './data/example_r3_egg-drop-chicken-noodle-soup.json'

# %%
def goodness(json_file):
    with open(file, 'r') as file:
    # Printing all the keys, for reference
    keys = []
    get_all_json_keys(data, keys)
    score = 0
    if "recipe_name" in keys:
        score += 10
    if "data_provenance" in keys:
        score += 10
    if "macronutrients" in keys:
        score += 10
    if "ingredients" in keys:
        score += 10
    if "instructions" in keys:
        score += 10
    return score
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Student Account/AppData/Local/Microsoft/WindowsApps/python3.11.exe" -m pip install ipykernel -U --user --force-reinstall'
